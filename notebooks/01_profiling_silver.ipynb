# %%
# IMPORTANDO BIBLIOTECAS
import sys
from pathlib import Path

# %%
# ENCONTRADO DIRETÓRIO DA SOURCE (src)
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
# IMPORTANDO MÓDULOS CRIADOS NA src
from src.silver.reader import read_bronze_table

# %%
df_municipio = read_bronze_table("municipio")

# %%
df_municipio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23995 entries, 0 to 23994
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ano                      23995 non-null  Int64
#  1   id_municipio             23995 non-null  object
#  2   id_municipio_nome        23995 non-null  object
#  3   serie                    23995 non-null  object
#  4   rede                     23995 non-null  object
#  5   taxa_alfabetizacao       23995 non-null  float64
#  6   media_portugues          23995 non-null  float64
#  7   proporcao_aluno_nivel_0  12448 non-null  float64
#  8   proporcao_aluno_nivel_1  12448 non-null  float64
#  9   proporcao_aluno_nivel_2  12448 non-null  float64
#  10  proporcao_aluno_nivel_3  12448 non-null  float64
#  11  proporcao_aluno_nivel_4  12448 non-null  float64
#  12  proporcao_aluno_nivel_5  12448 non-null  float64
# ...

# %%
df_municipio[
    ["ano", "id_municipio", "rede", 'serie']
].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_municipio['serie'].value_counts(dropna = False)
# Out:
# serie
# 2° ano do Ensino Fundamental    23995
# Name: count, dtype: int64

# %%
df_uf = read_bronze_table("uf")
df_uf['serie'].value_counts(dropna = False)
# Out:
# serie
# 2° ano do Ensino Fundamental    145
# Name: count, dtype: int64

# %%
df_uf[["ano", "sigla_uf", "rede"]].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_meta_municipio = read_bronze_table("meta_municipio")

# %%
df_meta_municipio["rede"].value_counts(dropna = False)
# Out:
# rede
# Municipal    10704
# Name: count, dtype: int64

# %%
df_meta_municipio[
    ["ano", "id_municipio"]
].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_meta_uf = read_bronze_table("meta_uf")

# %%
df_meta_uf["rede"].value_counts(dropna=False)
# Out:
# rede
# Pública    81
# Name: count, dtype: int64

# %%
df_meta_uf[
    ["ano", "sigla_uf"]
].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_meta_brasil = read_bronze_table("meta_brasil")
df_meta_brasil
# Out:
#     ano     rede  taxa_alfabetizacao  meta_alfabetizacao_2024  \
# 0  2025  Pública                66.0                     60.0
# 1  2024  Pública                59.2                     59.9
# 2  2023  Pública                55.9                     59.9
#
#    meta_alfabetizacao_2025  meta_alfabetizacao_2026  meta_alfabetizacao_2027  \
# 0                    64.00                    67.00                    71.00
# 1                    63.77                    67.47                    70.97
# 2                    63.77                    67.47                    70.97
#
#    meta_alfabetizacao_2028  meta_alfabetizacao_2029  meta_alfabetizacao_2030  \
# 0                    74.00                    77.00                     80.0
# 1                    74.23                    77.24                     80.0
# 2                    74.23                    77.24                     80.0
#
#    percentual_participacao              _ingestion_ts            _source  \
# ...

# %%
df_meta_brasil[["ano"]].duplicated().sum()
# Out:
# np.int64(0)
